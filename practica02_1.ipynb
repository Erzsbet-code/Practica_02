# %% [markdown]
# # Genómica Computacional
# ## Nombre: Olvera Martínez Jennifer Erzsebet
# ## Práctica 02 - Herramientas bioinformáticas (Python)

# %% [markdown]
# 1) Escribir un programa que me permita aplicar el 10% de descuento si la compra total es mayor a $100.

# %%
compra_total = float(input("Total: $"))
if compra_total > 100:
    descuento = compra_total * 0.10
    precio_final = compra_total - descuento
    print (f"El precio final a pagar es de: ${precio_final:.2f}")
else:
    print("No aplica el 10% de descuento")
# Out:
# Total: $500
# El precio final a pagar es de: $450.00

# %% [markdown]
# 2) Sabiendo que la fórmula para obtener el área de un triángulo es a = (b x h) / 2, donde b es la longitud de la base del triángulo, y h es su altura. Escribir un programa que permita realizar el cálculo del área de un triángulo. Si el área contiene valores decimales, imprimir el resultado con dos dígitos.

# %%
base = float(input("Longitud de la base: "))
altura = float(input("Valor de la altura: "))
area_triangulo= base * altura / 2
print (f"El área del triángulo es de: {area_triangulo:.2f}")
# Out:
# Longitud de la base: 55
# Valor de la altura: 67
# El área del triángulo es de: 1842.50

# %% [markdown]
# 3) La fórmula para el Índice de Masa Corportal es *IMC = kg/m2* donde kg es el peso de la persona en kilogramos y m2 es la altura en metros al cuadrado. Realizar un programa que calcula el IMC cuando se le provee el peso y la altura.

# %%
peso = float(input("Digite su peso en kilogramos: "))
altura = float(input("Digite su altura en metros: "))
IMC = peso / altura ** 2
print(f"Su índice de masa corporal es de: {IMC:.2f}")
# Out:
# Digite su peso en kilogramos: 54
# Digite su altura en metros: 1.62
# Su índice de masa corporal es de: 20.58
